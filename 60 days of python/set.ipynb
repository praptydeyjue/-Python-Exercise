# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}

# %%
set1.add(6)
set1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set2={4,5,6,7,8}
set2.update()
set2
# Out:
# {4, 5, 6, 7, 8}

# %%
set1.remove(4)
set1.discard(3)
set1
# Out:
# {1, 2, 5, 6}

# %%
set1={1,2,3,4,5,6,7}
set1.difference (set2)
# Out:
# {1, 2, 3}

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set2.difference_update(set1)
set2
# Out:
# {8}

# %%
set2
# Out:
# {8}

# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}
set1.intersection(set2)
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}
set1.intersection_update(set2)
set1
# Out:
# {4, 5}

# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}
set2.union(set1)
set2
# Out:
# {4, 5, 6, 7, 8}

# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}
set2.symmetric_difference(set1)
set2
# Out:
# {4, 5, 6, 7, 8}

# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}
set2.symmetric_difference_update(set1)
set2
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
set1.issubset(set2)
# Out:
# False

# %%
set1.isdisjoint(set2)
# Out:
# False

# %%
set1.issuperset(set2)
# Out:
# False

# %%
set1.pop()
set1
# Out:
# {2, 3, 4, 5}

# %%
set1.remove(3)
set1
# Out:
# {2, 4, 5}

# %% [markdown]
# FROZEN SET

# %%
s1={1,4,7,2,6,4}
s2=frozenset(s1)
set2
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
#list to frozenset
list1=[1,2,3,4,5]
x=frozenset(list1)
x
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
li1st1=[list(s2) for x in s2]
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
type(list1)
# Out:
# list

# %%
tup=(tuple(set2) for x in set2)
tup
# Out:
# <generator object <genexpr> at 0x0000027F6A1D7B90>

# %%
type(tup)
# Out:
# generator

# %%
set1=(set(s2) for x in s2)
set1
# Out:
# <generator object <genexpr> at 0x0000027F6A1D41E0>

# %%
type(set1)
# Out:
# generator
