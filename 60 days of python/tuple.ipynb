# %%
tup1=('data',2,4,6,[9,6],(5,3),True,False)
type(tup1)
# Out:
# tuple

# %%
tup1[0]
tup1[-2]
tup1[:3]
tup1[2:]
tup1[2:8]
tup1[4][1]
tup1(1,7,-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       5 tup1[2:8]
#       6 tup1[4][1]
# ----> 7 tup1(1,7,-1)
#
# TypeError: 'tuple' object is not callable

# %%
tup=(2)
type(tup)
# Out:
# int

# %%
tup=(2,)
type(tup)
# Out:
# tuple

# %%
tup2=(2,4,6,8,9)
tup2.count(4)
del tup2 
#tuple has no attribute pop,clear,add,extend,reverse etc. at first, tuple is converted into list.
#than use all this function and change in tuple again.
tup2=(1,2,3,5,6)
list1=list(tup2)
list1
type(list1)
list1.pop()
list1.pop(2)
list1
# Out:
# [1, 2, 5]

# %%
list1.append(10)
list1
# Out:
# [1, 2, 5, 10, 10, 10]

# %%
tup2=tuple(list1)
tup2
# Out:
# (1, 2, 5, 10)

# %%
for i in tup2:
    print(i)
# Out:
# 1
# 2
# 5
# 10

# %%
tup1=('data',2,4,6,[9,6],(5,3),True,False)
for i in tup1:
    print(i)
# Out:
# data
# 2
# 4
# 6
# [9, 6]
# (5, 3)
# True
# False
