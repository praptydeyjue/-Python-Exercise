# %%
line= 'i love my country'

# %%
line.upper()
# Out:
# 'I LOVE MY COUNTRY'

# %%
line.lower()
# Out:
# 'i love my country'

# %%
line.swapcase()
# Out:
# 'I LOVE MY COUNTRY'

# %%
line.split()
# Out:
# ['i', 'love', 'my', 'country']

# %%
line.replace('country','mother')
# Out:
# 'i love my mother'

# %%
line
# Out:
# 'i love my country'

# %%
line.casefold()
# Out:
# 'i love my country'

# %%
line.capitalize()
# Out:
# 'I love my country'

# %%
line.title()
# Out:
# 'I Love My Country'

# %%
line.encode()
# Out:
# b'i love my country'

# %%
len(line)
# Out:
# 17

# %%
line.count('o')
# Out:
# 2

# %%
line.find('m')
# Out:
# 7

# %%
line.find('m', 0, 17)
# Out:
# 7

# %%
line.center(100)
# Out:
# '                                         i love my country                                          '

# %%
type(line)
# Out:
# str

# %%
line.split()
line.split()[2]
# Out:
# 'my'

# %%
line.replace('my','own')
# Out:
# 'i love own country'

# %%
x= 100
print(f'i have {x} taka')
# Out:
# i have 100 taka

# %%
x=1000
print('i have {} tk only'. format(x))
# Out:
# i have 1000 tk only

# %%
sub='my name is prapty'
sub.islower()
sub.isupper()
sub.isnumeric()
sub.istitle()
# Out:
# False

# %%
sub= 'data science'
sub.index('s')
sub.index('c',2,10)
# Out:
# 6

# %% [markdown]
# data type

# %%
x='data type'
type(x)
# Out:
# str

# %%
a=1000
type(a)
# Out:
# int

# %%
a=10.5
type(a)
# Out:
# float

# %%
a=10+5j
type(a)
# Out:
# complex

# %%
x=[1,2,5,9,8]
type(x)
# Out:
# list

# %%
y=(7,4,9,2,8)
type(y)
# Out:
# tuple

# %%
z={5,6,7,9,8}
type(z)
# Out:
# set

# %%
z={5,6,7,9,8}
set=frozenset(z)
type(set)
# Out:
# frozenset

# %%
5 in z
# Out:
# True

# %%
3 in z
# Out:
# False

# %%
a=int(input())
b=int(input())
result= a-b
print(result)
# Out:
# 5

# %%
b=4+int('4')
print(b)
type(b)
# Out:
# 8
# int
