# %%
list1=[1,2,3,True,False,(5,7,9)]
type(list1)
# Out:
# list

# %%
list1[5]
list1[5][1]
list1[2:]
list1[:5]
# Out:
# [1, 2, 3, True, False]

# %%
list1[2] = 'data'
list1
list1.append(10.5)
list1
# Out:
# [1, 2, 'data', True, False, (5, 7, 9), 10.5]

# %%
import sys
sys.getsizeof(list1)
# Out:
# 152

# %%
list1.pop()
list1.pop(2)
list1
# Out:
# [1, 2, True, False, (5, 7, 9)]

# %%
list1.copy()
list1
# Out:
# [1, 2, True, False, (5, 7, 9)]

# %%
list1.extend('True')
list1
# Out:
# [1, 2, 3, True, False, (5, 7, 9), 'T', 'r', 'u', 'e']

# %%
list1.insert(2, 'prapty')
list1
# Out:
# [1, 2, 'prapty', True, False, (5, 7, 9), 'e', 'g', 'g']

# %%
list1
# Out:
# [1, 2, 'prapty', True, False, (5, 7, 9), 'e', 'g', 'g']

# %%
list1.count(2)
# Out:
# 1

# %%
list1.reverse()
list1
# Out:
# ['g', 'g', 'e', (5, 7, 9), False, True, 'prapty', 2, 1]

# %%
list1.remove(2)
list1
# Out:
# ['g', 'g', 'e', (5, 7, 9), 'prapty']

# %%
list1.clear()
list1
# Out:
# []
