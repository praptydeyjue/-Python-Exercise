# %%
x=200
y=100
x+y
# Out:
# 300

# %%
x-y
# Out:
# 100

# %%
x*y
# Out:
# 20000

# %%
x/y
# Out:
# 2.0

# %%
x//y
# Out:
# 2

# %%
x%y
# Out:
# 0

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %%
x=5000
y=5000
x==y # bcz of their same value.
# Out:
# True

# %%
x is y # x and y have not same id.
# Out:
# False

# %%
x=2
y=3
x & y
# Out:
# 2

# %%
x|y
# Out:
# 3

# %%
x^y
# Out:
# 1

# %%
y~x
# Out:
#   Cell In[27], line 1
#     y~x
#      ^
# SyntaxError: invalid syntax

# %%
x!=y
# Out:
# True

# %%
x<y
# Out:
# True

# %%
x>y
# Out:
# False

# %%
x=2
x+=5
x
# Out:
# 7

# %%
x-=5
x
# Out:
# -8
