# %% [markdown]
# #### 1.Sum of List Elements
#
# - Problem Description:
#   Sum of List Elements:
#   Write a Python function that calculates the sum of all elements in a given list of integers.
# - Parameters:
#   numbers (List of integers): The input list containing integers.

# %%
## Function to use sum of list elements
def sum_list(numbers):
     return sum(numbers)
numbers = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_sum = sum_list(numbers)
print(f"The sum of the list elements is {numbers}: {result_sum}")
# Out:
# The sum of the list elements is [1, 2, 3, 4, 5]: 15

# %% [markdown]
# #### 2. Largest Element in a List
#
# - Find the Largest Element in a List:
#   Write a Python function that finds and returns the largest element in a given list of integers.
# - Parameters:
#   numbers (List of integers): The input list containing integers.
# - Returns:
#   An integer representing the largest element in the input list.

# %%
## Function to use Largest Element in a List
def find_largest(numbers):
    return max(numbers)
numbers = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_largest = find_largest(numbers)
print(f"The largest element in the list {numbers} is: {result_largest}")
# Out:
# The largest element in the list [3, 8, 2, 10, 5] is: 10

# %% [markdown]
# #### 3. Remove Duplicate in a List
#
# - Remove Duplicates from a List :
#   You are given a list of integers. Write a Python program that removes any duplicate elements from the list and returns a new list with only unique elements. The order of elements in the list should be maintained.
# - Parameters:
#   lst (List of integers): The list of integers from which duplicates should be removed.
# - Returns:
#   A list of integers where all duplicates have been removed, preserving the original order.

# %%
## Function to use Remove Duplicate in a list
def remove_duplicates(lst):
    return list(set(lst))
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_no_duplicates = remove_duplicates(lst)
print(f"The list after removing duplicates from {lst} is: {result_no_duplicates}")
# Out:
# The list after removing duplicates from [1, 2, 2, 3, 4, 4, 5] is: [1, 2, 3, 4, 5]

# %% [markdown]
# #### 4. Check if all elements in a List are Unique
#
# - Check if All Elements in a List are Unique
#   You are given a list of integers. Write a Python program that checks if all elements in the list are unique. If all elements are unique, return True; otherwise, return False.
# - Parameters:
#   lst (List of integers): The list of integers to check for uniqueness.
# - Returns:
#   A boolean value True if all elements in the list are unique, False otherwise.

# %%
## Function to check if all elements in a list are unique
def check_unique(lst):
    return len(lst) == len(set(lst))
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_unique = check_unique(lst)
print(f"Are all elements in the list {lst} unique: {'True' if result_unique else 'False'}")
# Out:
# Are all elements in the list [1, 2, 2, 3, 4, 5, 4] unique: False

# %% [markdown]
# #### 5. Reverse a List
#
# - Reverse a List (Non-Slicing Approach)
#   You are given a list of integers. Write a Python program that reverses the list without using slicing (lst[::-1]). The program should return the reversed list.
# - Parameters:
#   lst (List of integers): The list of integers to be reversed.
# - Returns:
#   A list of integers where the order of elements is reversed from the input list.

# %%
## Function to use Reverse a List (Non-Slicing Approach)
def reverse_list(lst):
    reversed_lst = []
    for item in lst:
        reversed_lst.insert(0, item) # Insert at the beginning
    return reversed_lst
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_reversed = reverse_list(lst)
print(f"The reversed list of {lst} is: {result_reversed}")
# Out:
# The reversed list of [1, 2, 3, 4, 5] is: [5, 4, 3, 2, 1]

# %% [markdown]
# #### 6. Number of Odd and Even Elements in a list
#
# - Count Even and Odd Numbers in a List:
#   You are given a list of integers. Write a Python program that counts and returns the number of even and odd numbers in the list.
#   -Parameters:
#   lst (List of integers): The list of integers where you will count the even and odd numbers.
# - Returns:
#   A tuple (even_count, odd_count) where even_count is the number of even numbers and odd_count is the number of odd numbers.

# %%
## Function to use Count Even and Odd Numbers in a List
def count_even_odd(lst):
    even_count = sum(1 for x in lst if x % 2 == 0)
    odd_count = sum(1 for x in lst if x % 2 != 0 )
    return even_count, odd_count
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_even_count, result_odd_count = count_even_odd(lst)
print(f"The number of even numbers in the list {lst} is : {result_even_count}")
print(f"The number of odd numbers in the list {lst} is: {result_odd_count}")
# Out:
# The number of even numbers in the list [1, 2, 3] is : 1
# The number of odd numbers in the list [1, 2, 3] is: 2

# %%
# Function to use A tuple (even_count, odd_count) where even_count is the number of even numbers and odd_count is the number of odd numbers.
def count_even_odd_tuple(lst):
    even_count = sum(1 for x in lst if x % 2 == 0)
    odd_count = sum(1 for x in lst if x % 2 != 0)
    return (even_count, odd_count)
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_even_odd_tuple = count_even_odd_tuple(lst)
print(f"The tuple of even and odd counts for the list {lst} is: {result_even_odd_tuple}")
# Out:
# The tuple of even and odd counts for the list [1, 2, 3] is: (1, 2)

# %% [markdown]
# #### 7. Check if List is Subset of Another List
#
# - You are given two lists of integers. Write a Python program that checks whether the first list is a subset of the second list using a brute-force approach, without using the in keyword. A list is considered a subset if all elements of the first list are present in the second list.
# - Parameters:
# - lst1 (List of integers): The first list, which is being checked as a subset.
# - lst2 (List of integers): The second list, which is the list to compare against.
# - Returns:
# - A boolean value True if lst1 is a subset of lst2, otherwise False.

# %%
## Check if a List is a Subset of Another List (Brute Force Approach)
def is_subset(list1, list2):
    for item in list1:
        if item not in list2:
            return False
    return True
list1 = [int(x) for x in input("Enter the first list of integers separated by spaces: ").split()]
list2 = [int(x) for x in input("Enter the second list of integers separated by spaces: ").split()]
result_subset = is_subset(list1, list2) 
print(f"Is the first list {list1} a subset of the second list {list2}: {'True' if result_subset else 'False'}")
# Out:
# Is the first list [1, 2, 3] a subset of the second list [1, 2, 3, 4, 5]: True

# %% [markdown]
# #### 8. Maximum Difference between 2 consecutive elements in a List
#
# - Find Maximum Difference Between Two Consecutive Elements (Brute Force Approach)
# - You are given a list of integers. Write a Python program to find the maximum difference between two consecutive elements in the list using a brute-force approach. The difference is defined as the absolute value of the difference between two consecutive elements.
# - Parameters: lst (List of integers): A list of integers.
# - Returns: An integer representing the maximum difference between two consecutive elements.

# %%
## Find Maximum Difference Between Two Consecutive Elements (Brute Force Approach)
def max_consecutive_difference(lst):
    if len(lst) < 2:
        return 0
    max_diff = 0
    for i in range(len(lst) - 1):
        diff = abs(lst[i] - lst[i + 1])
        if diff > max_diff:
            max_diff = diff
    return max_diff
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
result_max_diff = max_consecutive_difference(lst)
print(f"The maximum difference between two consecutive elements in the list {lst} is: {result_max_diff}")
# Out:
# The maximum difference between two consecutive elements in the list [1, 7, 3, 10, 5] is: 7

# %% [markdown]
# #### 9.Merge two sorted List
#
# - Merge Two Sorted Lists
# - You are given two sorted lists of integers. Write a Python function to merge these two sorted lists into one sorted list. The resulting list should also be in non-decreasing order.
# - Parameters: list1 (List of integers): The first sorted list. list2 (List of integers): The second sorted list.
# - Returns: A single list of integers, containing all elements from list1 and list2, sorted in non-decreasing order.

# %%
##Merge Two Sorted Lists 
def merge_two_sorted_lists(list1, list2):
    merged_list = []
    i, j = 0, 0
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merged_list.append(list1[i])
            i += 1
        else:
            merged_list.append(list2[j])
            j += 1
    # Append remaining elements
    merged_list.extend(list1[i:])
    merged_list.extend(list2[j:])
    return merged_list
list1 = [int(x) for x in input("Enter the first sorted list of integers separated by spaces: ").split()]
list2 = [int(x) for x in input("Enter the second sorted list of integers separated by spaces: ").split()]
result_merged_list = merge_two_sorted_lists(list1, list2)
print(f"The merged sorted list from {list1} and {list2} is: {result_merged_list}")
# Out:
# The merged sorted list from [1, 3, 5] and [2, 4, 6] is: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# #### 10. Rotate a List
#
# - Rotate a List (Without Slicing)
# - You are given a list of integers and an integer k. Write a Python function to rotate the list to the right by k positions without using slicing. A rotation shifts elements from the end of the list to the front.
# - Parameters:
# - lst (List of integers): The list to be rotated.
# - k (Integer): The number of positions to rotate the list.
# - Returns:
# - A list of integers rotated by k positions.

# %%
## Rotate a List (Without Slicing)
def rotate_list(lst, k):
    n = len(lst)
    k = k % n  # Handle cases where k is larger than the list size
    rotated_list = []
    for i in range(n):
        rotated_list.append(lst[(i - k) % n])  # Calculate new index after rotation
    return rotated_list
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
k = int(input("Enter the number of positions to rotate the list: "))
result_rotated_list = rotate_list(lst, k)
print(f"The list {lst} rotated by {k} positions is: {result_rotated_list}")
# Out:
# The list [1, 2, 3, 4, 5] rotated by 2 positions is: [4, 5, 1, 2, 3]

# %%
## Rotate a List (Without Slicing)
def rotate_list(lst, k):
    # Handling the case where the list is empty
    if not lst:
        return []
    
    # Modulo to handle the case where k is greater than the length of the list
    k = k % len(lst)
    
    # Brute force approach using loops
    for _ in range(k):
        last_element = lst.pop()  # Remove the last element
        lst.insert(0, last_element)  # Insert it at the front
    
    return lst
lst = [int(x) for x in input("Enter a list of integers separated by spaces: ").split()]
k = int(input("Enter the number of positions to rotate the list: "))
result_rotated_list = rotate_list(lst, k)
print(f"The list {lst} rotated by {k} positions is: {result_rotated_list}")
# Out:
# The list [4, 5, 1, 2, 3] rotated by 2 positions is: [4, 5, 1, 2, 3]

# %% [markdown]
# #### 11. Merge 2 list into Dictionary
#
# - Merge Lists to Dictionary
# - Design a Python function named.merge_lists_to_dictionary to merge two lists into a dictionary where elements from the first list act as keys and elements from the second list act as values.
# - Parameters: - keys (List): A list of keys. - values (List): A list of values.
# - Returns: - A dictionary containing merged key-value pairs.

# %%
##  Merge 2 list into Dictionary
def merge_lists_to_dictionary(keys, values):
    if len(keys) != len(values):
        raise ValueError("Keys and values lists must have the same length.")
    return dict(zip(keys, values))
keys = [x for x in input("Enter keys separated by spaces: ").split()]
values = [x for x in input("Enter values separated by spaces: ").split()]
result_merged_dict = merge_lists_to_dictionary(keys, values)
print(f"The merged dictionary from keys {keys} and values {values} is: {result_merged_dict}")
# Out:
# The merged dictionary from keys ['a', 'b', 'c'] and values ['1', '2', '3'] is: {'a': '1', 'b': '2', 'c': '3'}

# %%
def merge_lists_to_dictionary(keys, values):
    # Boundary Condition to check for equal length of keys and values.
    # Last point in problem solving framework :)
    if(len(keys) != len(values)):
        return False
    # Create an empty dictionary to store the result
    result = {}
 
    # Use a loop to iterate through both lists
    for i in range(len(keys)):
        # Add each key-value pair to the dictionary
        result[keys[i]] = values[i]
 
    return result
keys = [x for x in input("Enter keys separated by spaces: ").split()]
values = [x for x in input("Enter values separated by spaces: ").split()]
result_merged_dict = merge_lists_to_dictionary(keys, values)
print(f"The merged dictionary from keys {keys} and values {values} is: {result_merged_dict}")
# Out:
# The merged dictionary from keys ['a', 'b', 'c'] and values ['1', '2', '3'] is: {'a': '1', 'b': '2', 'c': '3'}

# %% [markdown]
# #### 12. Merge Multiple Dictionary
#
# - Merge Three Dictionaries : Design a Python function named merge_three_dictionaries to merge exactly three dictionaries into one.
# - Parameters: - dict1 (Dictionary): The first dictionary to be merged. - dict2 (Dictionary): The second dictionary to be merged. - dict3 (Dictionary): The third dictionary to be merged
# - Returns:- A single dictionary containing all key-value pairs from the three input dictionaries.

# %%
## Merge Three Dictionary
def merge_three_dictionaries(dict1, dict2, dict3):
    merged_dict = {}
    for d in (dict1, dict2, dict3):
        merged_dict.update(d)
    return merged_dict
dict1 = eval(input("Enter the first dictionary: "))
dict2 = eval(input("Enter the second dictionary: "))
dict3 = eval(input("Enter the third dictionary: "))
result_merged_dict = merge_three_dictionaries(dict1, dict2, dict3)
print(f"The merged dictionary from {dict1}, {dict2}, and {dict3} is: {result_merged_dict}")
# Out:
# The merged dictionary from {'a': 1, 'b': 2}, {'c': 3, 'd': 4}, and {'f': 5, 'g': 6} is: {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'f': 5, 'g': 6}

# %% [markdown]
# #### 13.Words Frequency in a Sentence
#
# - Count Word Frequency : Design a Python function named count_word_frequency to count the frequency of words in a sentence and store the counts in a dictionary.
# - Parameters: - sentence (str): The input sentence where you need to count the frequency of each word.
# - Returns: - A dictionary where the keys are words from the sentence and the values are their corresponding frequencies.

# %%
## Count Word Frequency
def count_word_frequency(sentence):
    words = sentence.split()
    frequency = {}
    for word in words:
        frequency[word] = frequency.get(word, 0) + 1
    return frequency 
sentence = input("Enter a sentence: ")
result_word_frequency = count_word_frequency(sentence)
print(f"The word frequency in the sentence '{sentence}' is: {result_word_frequency}")
# Out:
# The word frequency in the sentence 'hello world hello' is: {'hello': 2, 'world': 1}

# %% [markdown]
# #### 14. Palindromic Tuple
#
# - Check if Tuple is Palindromic: - Design a Python function named is_palindromic_tuple to check if a tuple is palindromic, meaning it reads the same forwards and backwards.
# - Parameters:- tup (tuple): The input tuple that you need to check for palindromic property.
# - Returns: - True if the tuple is palindromic, False otherwise.

# %%
## Check if Tuple is Palindromic
def is_palindromic_tuple(tup):
    return tup == tup[::-1]
tup = eval(input("Enter a tuple: "))
result_palindromic = is_palindromic_tuple(tup)
print(f"Is the tuple {tup} palindromic: {'True' if result_palindromic else 'False'}")
# Out:
# Is the tuple ('a', 'b', 'c', 'b', 'a') palindromic: True

# %% [markdown]
# #### 15.Merge Dictionaries with Common Keys
#
# - Merge Dictionaries with Overlapping Keys
# - Design a Python function named merge_dicts_with_overlapping_keys that merges multiple dictionaries into a single dictionary. If a key appears in more than one dictionary, sum up their values.
# - Parameters: - dicts (list): A list of dictionaries where keys might overlap.
# - Returns: - A single dictionary where values for overlapping keys are summed.

# %%
## Merge Dictionaries with Overlapping Keys
def merge_dicts_with_overlapping_keys(dicts):
    merged_dict = {} # Initialize an empty dictionary to hold the merged result
    for d in dicts:
        for key, value in d.items():
            if key in merged_dict:
                merged_dict[key] += value
            else:
                merged_dict[key] = value
    return merged_dict
dicts = [] # List to hold multiple dictionaries
num_dicts = int(input("Enter the number of dictionaries to merge: "))
for i in range(num_dicts):
    d = eval(input(f"Enter dictionary {i + 1}: "))
    dicts.append(d) 
result_merged_dict = merge_dicts_with_overlapping_keys(dicts)
print(f"The merged dictionary with overlapping keys is: {result_merged_dict}")
# Out:
# The merged dictionary with overlapping keys is: {'a': 1, 'b': 5, 'c': 4}
