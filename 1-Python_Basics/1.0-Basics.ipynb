# %% [markdown]
# ### Syntax and Semantics in Python

# %% [markdown]
#  <h2>Outline:</h2>
#  <ul>
#   <li>Single line Comments and multiline comments</li>
#   <li>Definition of Syntax and Semantics</li>
#   <li>Basic Syntax Rules in Pythonk</li>
#   <li>Understanding Semantics in Python</li>
#   <li>Common Syntex Errors and How to Avoid Them</li>
#   <li>Pratical Code Examples</li>
# </ul>

# %%
##Basic Syntex Rules in Python
##Case Sensitivity - Python is case sensitive

name="Tushar"
Name="DebNath"

print(name)
print(Name)
# Out:
# Tushar
# DebNath

# %%
##Indentation
##Python uses indentation to defne blocks of code. Consistent use of spaces(commonly 4) or a tab is required.
age =32
if age>30:
    print(age)
    
print(age) # This is outside block
# Out:
# 32
# 32

# %%
##This is a sigle line comment
print("Hello world")
# Out:
# Hello world

# %%
##Line continuation
## Use a backlash (\) to continue a statement to the next line
total=1+2+3+4+5+6+7+ \
    4+5+6
print(total)
# Out:
# 43

# %%
##Multiple Statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Understand Semnatics In Python
# Variable assignment
age=33 ##age is an integer
name="DebNath" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
##Type Inference
var=10
print(type(var))
var="Tushar"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Name Error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 ## Name Error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
##Code examples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
